# %%
f = open("raised_amounts_1.txt", "r")
for line in f:
    try:
        line = line.strip()
        index_first_comma = line.index(",")
        url = line[:index_first_comma]
        rest = line[index_first_comma:]
        index_raised_amount = rest.index("raised")
        if index_raised_amount == -1:
            index_raised_amount = rest.index("gesammelt")
        raised_amount = rest[:index_raised_amount]
    except Exception as e:
        print(line, e)
f.close()
# Out:
# , $383
# , $1,680
# , $1,120
# , $10
# , $260
# , $13,410
# , $125
# , $2,340
# , $2,440
# , $14,521
# , $650
# , $3,055
# https://www.gofundme.com/f/100th-video-fund-raiser-against-brain-tumors, $10,063gesammelt·207 Spenden, $10,063gesammelt, ·207 Spenden, substring not found
# , $4,010
# , $1,510
# , $775
# , $9,547
# , $900
# , $5,666
# , $540
# , $28,550
# , $2,170
# , $745
# https://www.gofundme.com/f/14-year-old-jassan-lindsey-tragedy, $20,319gesammelt·301 Spenden, $20,319gesammelt, ·301 Spenden, substring not found
# , $4,610
# https://www.gofundme.com/f/15th-annual-chs-toy-drive, $3,450gesammelt·65 Spenden, $3,450gesammelt, ·65 Spenden, substring not found
# , $1,197
# , $2,000
# , $2,360
# , $9,005
# , $5,595
# , $3,355
# , $4,586
# , $110
# , $2,000
# , $365
# , $1,076
# , $1,920
# , $5,338
# , $1,960
# , $305
# , $305
# , $4,695
# , $13,772
# , $4,325
# , $1,000
# , $515
# , $295
# , $10,506
# , $14,456
# , $5,435
# , $12,210
# , $1,045
# , $1,451
# , $250
# , $3,595
# ...
